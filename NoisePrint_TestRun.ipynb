# %%
from main_extraction import main_extraction, main_extraction_with_save

main_extraction_with_save('../Nat_Old/20180410_142549.jpg', '20180410_142549.npz')
# Out:
# INFO:tensorflow:Restoring parameters from /Users/adam/Desktop/Nat_SPNandNoiseprint/noiseprint_main/noiseprint/./nets/net_jpg101/model
# 2022-12-13 12:04:13.319713: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-13 12:04:13.320097: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 12. Tune using inter_op_parallelism_threads for best performance.
#  2268x4032 large 101

# %%
from main_showout import main_showout

main_showout('../Nat_Old/20180410_142549.jpg', '20180410_142549.npz')
# Out:
#  ../Nat_Old/20180410_142549.jpg
# size :  (2268, 4032, 3)
# time : 185.861
# qf   : 200

# %%
main_extraction_with_save('./demo/imgs/inpainting.png', 'inpainting.npz')
main_showout('./demo/imgs/inpainting.png', 'inpainting.npz')
# Out:
# INFO:tensorflow:Restoring parameters from /Users/adam/Desktop/Nat_SPNandNoiseprint/noiseprint_main/noiseprint/./nets/net_jpg101/model
#  512x512 small 101
#  ./demo/imgs/inpainting.png
# size :  (512, 512, 3)
# time : 5.39397
# qf   : 200

# %%
output = main_extraction('./demo/imgs/inpainting.png')
output['noiseprint']
# Out:
# INFO:tensorflow:Restoring parameters from /Users/adam/Desktop/Nat_SPNandNoiseprint/noiseprint_main/noiseprint/./nets/net_jpg101/model
#  512x512 small 101
# array([[-9.5483214e-01, -2.3940168e-02,  2.4399254e-01, ...,
#         -5.3296614e+00, -1.6425158e+01,  7.8029337e+00],
#        [ 2.1625457e+00, -8.3915567e-01, -2.2098787e-01, ...,
#          3.8430336e+01,  1.0403323e+02, -4.2069641e+01],
#        [-2.4912159e-01, -7.8137714e-01,  1.4805362e-02, ...,
#          3.8656569e+00,  1.5924918e+01, -8.3636112e+00],
#        ...,
#        [-1.6969547e-01, -3.8108236e-01,  2.6009905e-01, ...,
#         -4.6075962e-02,  5.4207599e-01, -1.8008643e-01],
#        [ 4.8330349e-01, -5.6857598e-01, -1.5458740e-01, ...,
#         -1.3333632e-01,  6.4456850e-01, -8.8554680e-01],
#        [ 8.5003984e-01, -2.1777071e-01,  3.5145068e-01, ...,
#          3.8785714e-01,  8.2914072e-01, -1.0670197e+00]], dtype=float32)

# %%
import numpy as np
im = np.load('inpainting.npz')
im['noiseprint']
# Out:
# array([[-9.5483214e-01, -2.3940168e-02,  2.4399254e-01, ...,
#         -5.3296614e+00, -1.6425158e+01,  7.8029337e+00],
#        [ 2.1625457e+00, -8.3915567e-01, -2.2098787e-01, ...,
#          3.8430336e+01,  1.0403323e+02, -4.2069641e+01],
#        [-2.4912159e-01, -7.8137714e-01,  1.4805362e-02, ...,
#          3.8656569e+00,  1.5924918e+01, -8.3636112e+00],
#        ...,
#        [-1.6969547e-01, -3.8108236e-01,  2.6009905e-01, ...,
#         -4.6075962e-02,  5.4207599e-01, -1.8008643e-01],
#        [ 4.8330349e-01, -5.6857598e-01, -1.5458740e-01, ...,
#         -1.3333632e-01,  6.4456850e-01, -8.8554680e-01],
#        [ 8.5003984e-01, -2.1777071e-01,  3.5145068e-01, ...,
#          3.8785714e-01,  8.2914072e-01, -1.0670197e+00]], dtype=float32)

# %%
inpainting_output
